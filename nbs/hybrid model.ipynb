# %%
import django_jupyter
django_jupyter.init()

# %%
from movies.models import Movie
from django.contrib.auth import get_user_model

User = get_user_model

# %%
def print_movie_genres(movie_id):
    """
    Print the genres associated with the movie.
    """
    try:
        movie = Movie.objects.get(id=movie_id)
        movie_genres = [genre.name for genre in movie.genres.all()]
        print(f"Movie ID: {movie_id} | Movie's Genres: {movie_genres}")
        return movie_genres
    except Movie.DoesNotExist:
        print(f"Movie with ID {movie_id} does not exist.")
        return []

# Test the function
movie_genres = print_movie_genres(movie_id=36120)  # Replace with an actual movie_id
# Out:
# Movie ID: 36120 | Movie's Genres: ['Drama', 'Thriller', 'Horror', 'Mystery']

# %%
import json

def print_user_genres(user_id):
    """
    Print the genres preferred by the user.
    """
    try:
        user = User.objects.get(id=user_id)
        # Parse the preferences JSON string into a Python dictionary
        preferences = json.loads(user.preferences)
        user_genres = preferences.get('genres', [])
        print(f"User ID: {user_id} | User's Preferred Genres: {user_genres}")
        return user_genres
    except User.DoesNotExist:
        print(f"User with ID {user_id} does not exist.")
        return []
    except json.JSONDecodeError:
        print(f"Error decoding JSON for user ID {user_id}.")
        return []

# Test the function
user_genres = print_user_genres(user_id=2653)  # Replace with an actual user_id
# Out:
# User ID: 2653 | User's Preferred Genres: ['Horror', 'Comedy', 'Romance', 'Thriller', 'Drama']

# %%
def calculate_genre_matching_score(user_id, movie_id):
    """
    Calculate the Genre Matching Score based on user's preferred genres and the movie's genres.
    """
    # Get the user's preferred genres
    user_genres = print_user_genres(user_id)
    
    # Get the movie's genres
    movie_genres = print_movie_genres(movie_id)
    
    # Calculate the matching score
    matching_genres = set(user_genres).intersection(set(movie_genres))
    genre_matching_score = len(matching_genres)
    
    print(f"User's Preferred Genres: {user_genres}")
    print(f"Movie's Genres: {movie_genres}")
    print(f"Genre Matching Score: {genre_matching_score}")
    
    return genre_matching_score

# Test the function
calculate_genre_matching_score(user_id=2653, movie_id=36120)  # Replace with actual IDs
# Out:
# User ID: 2653 | User's Preferred Genres: ['Horror', 'Comedy', 'Romance', 'Thriller', 'Drama']
# Movie ID: 36120 | Movie's Genres: ['Drama', 'Thriller', 'Horror', 'Mystery']
# User's Preferred Genres: ['Horror', 'Comedy', 'Romance', 'Thriller', 'Drama']
# Movie's Genres: ['Drama', 'Thriller', 'Horror', 'Mystery']
# Genre Matching Score: 3
# 3

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

# Test if Django models are accessible
print(User.objects.count(), "users found in the database.")
# Out:
# 5630 users found in the database.

# %%
def test_database_access():
    print("Testing database access...")
    ratings_query = Rating.objects.all()[:5]  # Fetch only 5 records for testing
    for rating in ratings_query:
        print(rating.user_id, rating.movie_id, rating.score)

test_database_access()
# Out:
# Testing database access...
# 4 2114 10.0
# 4 3060 10.0
# 4 3071 8.0
# 4 3169 8.0
# 4 3208 4.0

# %%
from surprise import Dataset, SVD, Reader
from surprise.model_selection import train_test_split
from django.contrib.auth import get_user_model
from ratings.models import Rating
from movies.models import Movie
import pandas as pd
import pickle
import json

User = get_user_model()

def get_ratings_dataset_with_genre_matching():
    """
    Fetches ratings data from the database and adds a Genre Matching Score.
    """
    print("Fetching ratings data from the database...")  # Debugging statement
    ratings_query = Rating.objects.all().values('user_id', 'movie_id', 'score')
    data = []
    
    print(f"Total ratings fetched: {len(ratings_query)}")  # Debugging statement
    
    for rating in ratings_query:
        user_id = rating['user_id']
        movie_id = rating['movie_id']
        score = rating['score']
        
        # Fetch user and movie genres
        user = User.objects.get(id=user_id)
        
        # Ensure that preferences are treated as a dictionary
        if isinstance(user.preferences, str):
            user.preferences = json.loads(user.preferences)
        
        user_genres = user.preferences.get('genres', [])
        movie_genres = list(Movie.objects.get(id=movie_id).genres.values_list('name', flat=True))
        
        print(f"User ID: {user_id} | User's Preferred Genres: {user_genres}")
        print(f"Movie ID: {movie_id} | Movie's Genres: {movie_genres}")
        
        genre_matching_score = len(set(user_genres) & set(movie_genres))
        
        # Adding genre matching score to the rating score
        adjusted_score = float(score) + genre_matching_score
        
        data.append((user_id, movie_id, adjusted_score))
    
    # Creating DataFrame
    ratings_df = pd.DataFrame(data, columns=['user', 'item', 'rating'])
    
    # Debugging prints
    print("Ratings DataFrame with Genre Matching Scores:")
    print(ratings_df.head())
    
    # Define the reader with the rating scale
    print("Defining Reader with rating scale...")
    reader = Reader(rating_scale=(0, 10 + max(ratings_df['rating'])))
    
    print("Loading dataset into Surprise format...")
    data = Dataset.load_from_df(ratings_df[['user', 'item', 'rating']], reader)
    
    return data

def train_model_with_genre_matching():
    """
    Trains the SVD model using the dataset with Genre Matching Scores and saves the trained model.
    """
    print("Starting the training process...")
    
    # Load the dataset with genre matching score
    data = get_ratings_dataset_with_genre_matching()
    
    # Train-test split
    print("Splitting data into training and test sets...")
    trainset, testset = train_test_split(data, test_size=0.2)
    
    print("Training the model with SVD algorithm...")
    algo = SVD(n_epochs=20, lr_all=0.01, reg_all=0.2)
    
    algo.fit(trainset)
    
    print("Model trained successfully.")
    
    # Save the trained model to a file
    model_path = r'C:\Users\Melarc.py\Documents\GitHub\FlixFinder\recommendation\models\trained_model_with_genre_matching.pkl'
    with open(model_path, 'wb') as file:
        pickle.dump(algo, file)
    
    print(f"Model trained with Genre Matching Score and saved successfully at {model_path}!")

# Run the function
train_model_with_genre_matching()
# Out:
# Starting the training process...
# Fetching ratings data from the database...
# Total ratings fetched: 37727
# User ID: 4 | User's Preferred Genres: ['Drama', 'Action']
# Movie ID: 2114 | Movie's Genres: ['Drama']
# User ID: 4 | User's Preferred Genres: ['Drama', 'Action']
# Movie ID: 3060 | Movie's Genres: ['Comedy']
# User ID: 4 | User's Preferred Genres: ['Drama', 'Action']
# Movie ID: 3071 | Movie's Genres: ['Family', 'Documentary']
# User ID: 4 | User's Preferred Genres: ['Drama', 'Action']
# Movie ID: 3169 | Movie's Genres: ['Animation', 'Family']
# User ID: 4 | User's Preferred Genres: ['Drama', 'Action']
# Movie ID: 3208 | Movie's Genres: ['Comedy', 'Romance', 'Drama', 'Science Fiction']
# User ID: 8 | User's Preferred Genres: ['Fantasy', 'Romance', 'Thriller', 'Comedy', 'Drama']
# Movie ID: 5650 | Movie's Genres: ['Comedy', 'Drama']
# User ID: 10 | User's Preferred Genres: ['Romance', 'Horror', 'Action']
# Movie ID: 735 | Movie's Genres: ['Unknown']
# User ID: 11 | User's Preferred Genres: ['Action', 'Comedy', 'Romance', 'Horror']
# Movie ID: 26614 | Movie's Genres: ['Thriller']
# User ID: 12 | User's Preferred Genres: ['Romance', 'Drama', 'Horror', 'Fantasy']
# Movie ID: 

# User ID: 23 | User's Preferred Genres: ['Romance', 'Action', 'Thriller', 'Sci-Fi']
# Movie ID: 27803 | Movie's Genres: ['Drama']
# User ID: 23 | User's Preferred Genres: ['Romance', 'Action', 'Thriller', 'Sci-Fi']
# Movie ID: 30820 | Movie's Genres: ['Animation', 'Comedy', 'Family']
# User ID: 23 | User's Preferred Genres: ['Romance', 'Action', 'Thriller', 'Sci-Fi']
# Movie ID: 32892 | Movie's Genres: ['Fantasy', 'Horror']
# User ID: 23 | User's Preferred Genres: ['Romance', 'Action', 'Thriller', 'Sci-Fi']
# Movie ID: 33903 | Movie's Genres: ['Romance', 'Drama']
# User ID: 26 | User's Preferred Genres: ['Drama', 'Fantasy', 'Romance']
# Movie ID: 4844 | Movie's Genres: ['Comedy']
# User ID: 26 | User's Preferred Genres: ['Drama', 'Fantasy', 'Romance']
# Movie ID: 31410 | Movie's Genres: ['Music']
# User ID: 26 | User's Preferred Genres: ['Drama', 'Fantasy', 'Romance']
# Movie ID: 31878 | Movie's Genres: ['Action', 'War']
# User ID: 29 | User's Preferred Genres: ['Horror', 'Sci-Fi', 'Action']
# Movie ID: 27822 | Movie's Genres: ['Documentary']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 869 | Movie's Genres: ['Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 1082 | Movie's Genres: ['Comedy', 'Horror']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 2114 | Movie's Genres: ['Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3071 | Movie's Genres: ['Family', 'Documentary']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3167 | Movie's Genres: ['Adventure', 'Romance', 'Drama', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3169 | Movie's Genres: ['Animation', 'Family']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3173 | Movie's Genres: ['Romance', 'Drama', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3185 | Movie's Genres: ['Documentary']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3198 | Movie's Genres: ['Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3204 | Movie's Genres: ['Comedy', 'Romance', 'Action']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3206 | Movie's Genres: ['Comedy', 'Crime', 'Mystery']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3334 | Movie's Genres: ['Comedy', 'Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3391 | Movie's Genres: ['Comedy', 'Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3394 | Movie's Genres: ['Comedy', 'Romance']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3441 | Movie's Genres: ['Action', 'Thriller', 'Science Fiction']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3445 | Movie's Genres: ['Comedy', 'Romance', 'Drama', 'Foreign']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3494 | Movie's Genres: ['Comedy', 'Family', 'Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3524 | Movie's Genres: ['Comedy', 'Crime']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3701 | Movie's Genres: ['Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3734 | Movie's Genres: ['Comedy', 'Crime', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3735 | Movie's Genres: ['Drama', 'Documentary']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3783 | Movie's Genres: ['Unknown']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3791 | Movie's Genres: ['Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3844 | Movie's Genres: ['Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3852 | Movie's Genres: ['Comedy', 'Adventure', 'Action', 'Crime', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3873 | Movie's Genres: ['Adventure', 'Romance', 'Drama', 'Action', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 3927 | Movie's Genres: ['Comedy', 'Adventure', 'Romance', 'Drama', 'Action']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4029 | Movie's Genres: ['Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4033 | Movie's Genres: ['Comedy', 'Adventure', 'Action', 'Crime', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4037 | Movie's Genres: ['Drama', 'Action']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4039 | Movie's Genres: ['Comedy', 'Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4041 | Movie's Genres: ['Action', 'Crime', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4102 | Movie's Genres: ['Comedy', 'Romance']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4111 | Movie's Genres: ['Action', 'Crime', 'Thriller', 'Mystery']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4122 | Movie's Genres: ['Comedy']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4126 | Movie's Genres: ['Unknown']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4128 | Movie's Genres: ['Comedy']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4132 | Movie's Genres: ['Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4214 | Movie's Genres: ['Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4263 | Movie's Genres: ['Romance', 'Drama', 'Foreign']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4318 | Movie's Genres: ['Animation', 'Adventure', 'Fantasy', 'Action', 'Thriller', 'Science Fiction']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4322 | Movie's Genres: ['Drama', 'Crime']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4570 | Movie's Genres: ['Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4573 | Movie's Genres: ['Comedy', 'Romance', 'Drama', 'Science Fiction', 'Foreign']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4608 | Movie's Genres: ['Comedy', 'Romance', 'Science Fiction']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4615 | Movie's Genres: ['Romance', 'Drama', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4627 | Movie's Genres: ['Comedy', 'Drama', 'Music']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4628 | Movie's Genres: ['Thriller', 'Horror', 'Mystery']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4629 | Movie's Genres: ['Comedy', 'Romance']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4639 | Movie's Genres: ['Documentary']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4713 | Movie's Genres: ['Drama', 'Crime', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4751 | Movie's Genres: ['Drama', 'Crime']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4830 | Movie's Genres: ['Comedy']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4832 | Movie's Genres: ['Action', 'Western']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4835 | Movie's Genres: ['Drama', 'Thriller']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4881 | Movie's Genres: ['Romance', 'Drama', 'History', 'War']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4898 | Movie's Genres: ['Romance', 'Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4951 | Movie's Genres: ['Drama']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 4978 | Movie's Genres: ['Animation', 'Family', 'Adventure', 'Fantasy']
# User ID: 30 | User's Preferred Genres: ['Drama', 'Horror']
# Movie ID: 
| User's Preferred Genres: ['Drama', 'Fantasy', 'Thriller']
# Movie ID: 3927 | Movie's Genres: ['Comedy', 'Adventure', 'Romance', 'Drama', 'Action']
# User ID: 38 | User's Preferred Genres: ['Comedy', 'Thriller']
# Movie ID: 4114 | Movie's Genres: ['Animation', 'Family', 'Adventure', 'Fantasy', 'Action']
# User ID: 38 | User's Preferred Genres: ['Comedy', 'Thriller']
# Movie ID: 4862 | Movie's Genres: ['Comedy', 'Fantasy', 'Romance', 'Science Fiction']
# User ID: 38 | User's Preferred Genres: ['Comedy', 'Thriller']
# Movie ID: 4936 | Movie's Genres: ['Romance', 'Drama']
# User ID: 38 | User's Preferred Genres: ['Comedy', 'Thriller']
# Movie ID: 7936 | Movie's Genres: ['Music', 'Documentary']
# User ID: 38 | User's Preferred Genres: ['Comedy', 'Thriller']
# Movie ID: 8239 | Movie's Genres: ['Drama']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 3910 | Movie's Genres: ['Romance', 'Drama', 'Western']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 4039 | Movie's Genres: ['Comedy', 'Romance', 'Drama']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 4691 | Movie's Genres: ['Drama', 'Thriller', 'Mystery']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 4936 | Movie's Genres: ['Romance', 'Drama']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 5490 | Movie's Genres: ['Drama', 'Action']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 5694 | Movie's Genres: ['Fantasy', 'Drama', 'Thriller']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 6385 | Movie's Genres: ['Drama', 'Action', 'Science Fiction']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 6725 | Movie's Genres: ['Action', 'Crime']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 7001 | Movie's Genres: ['Romance', 'Drama']
# User ID: 41 | User's Preferred Genres: ['Thriller', 'Romance', 'Horror']
# Movie ID: 7164 | Movie's Genres: ['Comedy']
# User ID: 43 | User's Preferred Genres: ['Comedy', 'Thriller', 'Fantasy', 'Sci-Fi']
# Movie ID: 3173 | Movie's Genres: ['Romance', 'Drama', 'Thriller']
# User ID: 43 | User's Preferred Genres: ['Comedy', 'Thriller', 'Fantasy', 'Sci-Fi']
# Movie ID: 3773 | Movie's Genres: ['Drama', 'Music']
# User ID: 45 | User's Preferred Genres: ['Sci-Fi', 'Comedy', 'Horror', 'Thriller']
# Movie ID: 5878 | Movie's Genres: ['Drama', 'Crime']
# User ID: 46 | User's Preferred Genres: ['Drama', 'Fantasy', 'Thriller', 'Action', 'Sci-Fi']
# Movie ID: 7004 | Movie's Genres: ['Comedy', 'Action']
# User ID: 46 | User's Preferred Genres: ['Drama', 'Fantasy', 'Thriller', 'Action', 'Sci-Fi']
# Movie ID: 26614 | Movie's Genres: ['Thriller']
# User ID: 48 | User's Preferred Genres: ['Comedy', 'Fantasy', 'Romance']
# Movie ID: 6223 | Movie's Genres: ['Comedy', 'Romance', 'Action', 'Thriller']
# ...
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3060 | Movie's Genres: ['Comedy']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3071 | Movie's Genres: ['Family', 'Documentary']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3107 | Movie's Genres: ['Comedy', 'Family', 'Romance', 'Drama']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3168 | Movie's Genres: ['Comedy', 'Family']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3173 | Movie's Genres: ['Romance', 'Drama', 'Thriller']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3181 | Movie's Genres: ['Comedy', 'Drama']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3362 | Movie's Genres: ['Animation', 'Comedy', 'Family', 'Adventure']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3363 | Movie's Genres: ['Drama', 'Crime', 'Thriller']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3412 | Movie's Genres: ['Comedy', 'Drama']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3441 | Movie's Genres: ['Action', 'Thriller', 'Science Fiction']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3698 | Movie's Genres: ['Comedy', 'Fantasy', 'Romance', 'Science Fiction']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3703 | Movie's Genres: ['Action', 'Thriller', 'Science Fiction']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3729 | Movie's Genres: ['Unknown']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3791 | Movie's Genres: ['Drama']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3844 | Movie's Genres: ['Romance', 'Drama']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3848 | Movie's Genres: ['Thriller', 'Horror', 'Mystery']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3858 | Movie's Genres: ['Romance', 'Drama']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3861 | Movie's Genres: ['Science Fiction']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3863 | Movie's Genres: ['Comedy', 'Family', 'Fantasy']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3868 | Movie's Genres: ['Drama']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3871 | Movie's Genres: ['Adventure', 'Romance', 'Drama', 'Action']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3893 | Movie's Genres: ['Comedy', 'Romance']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3906 | Movie's Genres: ['Romance', 'Drama', 'Western']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 3950 | Movie's Genres: ['Comedy', 'Romance']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 4206 | Movie's Genres: ['Romance', 'Drama']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 4239 | Movie's Genres: ['Adventure', 'Fantasy', 'Action', 'Thriller']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 4318 | Movie's Genres: ['Animation', 'Adventure', 'Fantasy', 'Action', 'Thriller', 'Science Fiction']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 4595 | Movie's Genres: ['Romance', 'Drama']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 4610 | Movie's Genres: ['Comedy', 'Romance']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 4641 | Movie's Genres: ['Comedy', 'Romance']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 4651 | Movie's Genres: ['Action', 'Thriller', 'Science Fiction']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 4746 | Movie's Genres: ['Thriller', 'Horror']
# User ID: 2490 | User's Preferred Genres: ['Romance', 'Drama']
# Movie ID: 

# User ID: 2491 | User's Preferred Genres: ['Comedy', 'Thriller', 'Horror']
# Movie ID: 6537 | Movie's Genres: ['Comedy', 'Fantasy', 'Action', 'Thriller']
# User ID: 2491 | User's Preferred Genres: ['Comedy', 'Thriller', 'Horror']
# Movie ID: 6807 | Movie's Genres: ['Adventure', 'Action', 'Science Fiction']
# User ID: 2491 | User's Preferred Genres: ['Comedy', 'Thriller', 'Horror']
# Movie ID: 8228 | Movie's Genres: ['Drama', 'Thriller']
# User ID: 2491 | User's Preferred Genres: ['Comedy', 'Thriller', 'Horror']
# Movie ID: 30810 | Movie's Genres: ['Animation', 'Family', 'Adventure']
# User ID: 2491 | User's Preferred Genres: ['Comedy', 'Thriller', 'Horror']
# Movie ID: 33679 | Movie's Genres: ['Drama', 'Action', 'History', 'War']
# User ID: 2491 | User's Preferred Genres: ['Comedy', 'Thriller', 'Horror']
# Movie ID: 34624 | Movie's Genres: ['Documentary']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 735 | Movie's Genres: ['Unknown']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3663 | Movie's Genres: ['Comedy']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3702 | Movie's Genres: ['Comedy', 'Romance', 'Drama', 'Music']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3703 | Movie's Genres: ['Action', 'Thriller', 'Science Fiction']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3708 | Movie's Genres: ['Comedy', 'Crime']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3727 | Movie's Genres: ['Comedy']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3739 | Movie's Genres: ['Thriller', 'Horror', 'Science Fiction']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3777 | Movie's Genres: ['Comedy', 'Drama', 'Music']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3827 | Movie's Genres: ['Drama', 'Thriller']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3843 | Movie's Genres: ['Comedy', 'Fantasy', 'Romance']
# User ID: 2497 | User's Preferred Genres: ['Drama', 'Thriller', 'Horror', 'Romance', 'Sci-Fi']
# Movie ID: 3942 | Movie's Genres: ['Comedy', 'Crime']
# User ID: 2498 | User's Preferred Genres: ['Action', 'Horror', 'Fantasy']
# Movie ID: 3440 | Movie's Genres: ['Comedy', 'Drama']
# User ID: 2499 | User's Preferred Genres: ['Drama', 'Thriller', 'Sci-Fi', 'Action', 'Horror']
# Movie ID: 3441 | Movie's Genres: ['Action', 'Thriller', 'Science Fiction']
# User ID: 2499 | User's Preferred Genres: ['Drama', 'Thriller', 'Sci-Fi', 'Action', 'Horror']
# Movie ID: 3791 | Movie's Genres: ['Drama']
# User ID: 2501 | User's Preferred Genres: ['Thriller', 'Action', 'Horror', 'Comedy', 'Sci-Fi']
# Movie ID: 3441 | Movie's Genres: ['Action', 'Thriller', 'Science Fiction']
# User ID: 2501 | User's Preferred Genres: ['Thriller', 'Action', 'Horror', 'Comedy', 'Sci-Fi']
# Movie ID: 3702 | Movie's Genres: ['Comedy', 'Romance', 'Drama', 'Music']
# User ID: 2501 | User's Preferred Genres: ['Thriller', 'Action', 'Horror', 'Comedy', 'Sci-Fi']
# Movie ID: 3703 | Movie's Genres: ['Action', 'Thriller', 'Science Fiction']

# %%
from surprise import Dataset, SVD, Reader
from surprise.model_selection import train_test_split
from django.contrib.auth import get_user_model
from ratings.models import Rating
from movies.models import Movie
import pandas as pd
import pickle
import json

User = get_user_model()

def get_ratings_dataset_with_genre_matching():
    """
    Fetches ratings data from the database and adds a Genre Matching Score.
    """
    ratings_query = Rating.objects.all().values('user_id', 'movie_id', 'score')
    data = []
    
    for rating in ratings_query:
        user_id = rating['user_id']
        movie_id = rating['movie_id']
        score = rating['score']
        
        # Fetch user and movie genres
        user = User.objects.get(id=user_id)
        
        # Ensure that preferences are treated as a dictionary
        if isinstance(user.preferences, str):
            user.preferences = json.loads(user.preferences)
        
        user_genres = user.preferences.get('genres', [])
        movie_genres = list(Movie.objects.get(id=movie_id).genres.values_list('name', flat=True))
        
        genre_matching_score = len(set(user_genres) & set(movie_genres))
        
        # Adding genre matching score to the rating score
        adjusted_score = float(score) + genre_matching_score
        
        data.append((user_id, movie_id, adjusted_score))
    
    # Creating DataFrame
    ratings_df = pd.DataFrame(data, columns=['user', 'item', 'rating'])
    
    # Define the reader with the rating scale
    reader = Reader(rating_scale=(0, 10 + max(ratings_df['rating'])))
    
    # Load the dataset into Surprise format
    data = Dataset.load_from_df(ratings_df[['user', 'item', 'rating']], reader)
    
    return data

def train_model_with_genre_matching():
    """
    Trains the SVD model using the dataset with Genre Matching Scores and saves the trained model.
    """
    # Load the dataset with genre matching score
    data = get_ratings_dataset_with_genre_matching()
    
    # Train-test split
    trainset, testset = train_test_split(data, test_size=0.2)
    
    # Train the SVD algorithm with optimized parameters
    algo = SVD(n_epochs=20, lr_all=0.01, reg_all=0.2)
    algo.fit(trainset)
    
    # Save the trained model to a file
    model_path = r'C:\Users\Melarc.py\Documents\GitHub\Backend\FlixFinder\recommendation\models\trained_model_with_genre_matching.pkl'
    with open(model_path, 'wb') as file:
        pickle.dump(algo, file)
    
    # Print a completion message
    print(f"Model training completed and saved successfully at {model_path}!")

# Run the function
train_model_with_genre_matching()
# Out:
# Model training completed and saved successfully at C:\Users\Melarc.py\Documents\GitHub\Backend\FlixFinder\recommendation\models\trained_model_with_genre_matching.pkl!

# %% [markdown]
# #### Hyperparameter Tuning with GridSearchCV

# %%
from surprise.model_selection import GridSearchCV
from surprise import SVD

def perform_hyperparameter_tuning():
    # Load the dataset with genre matching score
    data = get_ratings_dataset_with_genre_matching()
    
    # Define the parameter grid
    param_grid = {
        'n_epochs': [10, 20, 30],
        'lr_all': [0.005, 0.01, 0.02],
        'reg_all': [0.1, 0.2, 0.4]
    }
    
    # Perform grid search
    grid_search = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=5)
    grid_search.fit(data)
    
    # Output the best RMSE score and corresponding parameters
    print(f"Best RMSE score attained: {grid_search.best_score['rmse']}")
    print(f"Parameters that gave the best RMSE score: {grid_search.best_params['rmse']}")

    return grid_search.best_params['rmse']

# Run the hyperparameter tuning
best_params = perform_hyperparameter_tuning()
# Out:
# Best RMSE score attained: 1.8172603956125588
# Parameters that gave the best RMSE score: {'n_epochs': 10, 'lr_all': 0.02, 'reg_all': 0.2}

# %%
from surprise import SVD, accuracy
from surprise.model_selection import train_test_split
import pickle

def train_optimized_model():
    # Load the dataset with genre matching score
    data = get_ratings_dataset_with_genre_matching()
    
    # Train-test split
    trainset, testset = train_test_split(data, test_size=0.2)
    
    # Initialize the SVD algorithm with the best parameters
    algo = SVD(n_epochs=10, lr_all=0.02, reg_all=0.2)
    
    # Train the algorithm on the trainset
    algo.fit(trainset)
    
    # Save the trained model
    model_path = r'C:\Users\Melarc.py\Documents\GitHub\Backend\FlixFinder\recommendation\models\optimized_trained_model_with_genre_matching.pkl'
    with open(model_path, 'wb') as file:
        pickle.dump(algo, file)
    
    print(f"Optimized model trained and saved successfully at {model_path}!")

    # Evaluate the model on the test set
    predictions = algo.test(testset)
    
    # Calculate RMSE and MAE
    rmse = accuracy.rmse(predictions)
    mae = accuracy.mae(predictions)
    
    print(f"Evaluation completed. RMSE: {rmse}, MAE: {mae}")

# Run the function to train and evaluate the optimized model
train_optimized_model()
# Out:
# Optimized model trained and saved successfully at C:\Users\Melarc.py\Documents\GitHub\Backend\FlixFinder\recommendation\models\optimized_trained_model_with_genre_matching.pkl!
# RMSE: 1.8175
# MAE:  1.3989
# Evaluation completed. RMSE: 1.8175353534541847, MAE: 1.3988781552113536
